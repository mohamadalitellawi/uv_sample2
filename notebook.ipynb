# %%
import pandas as pd
import numpy as np

# %%
polling_data = 'https://murach.com/python_analysis/president_polls_2016.csv'
forest_fire_data = 'https://murach.com/python_analysis/RDS-2013-0009.4_SQLITE.zip'
social_survey_data = 'https://murach.com/python_analysis/gss_stata_with_codebook.zip'
sports_analytics_data = 'https://murach.com/python_analysis/shots.json'
mortality_data = 'https://murach.com/python_analysis/mortality.csv'

# %%
df = pd.read_csv(mortality_data)
df.to_pickle('mortality_data.pkl')

# %%
df = pd.read_pickle('mortality_data.pkl')
df
# Out:
#      Year    Age Group  Death Rate
# 0    1900    1-4 Years      1983.8
# 1    1901    1-4 Years      1695.0
# 2    1902    1-4 Years      1655.7
# 3    1903    1-4 Years      1542.1
# 4    1904    1-4 Years      1591.5
# ..    ...          ...         ...
# 471  2014  15-19 Years        45.5
# 472  2015  15-19 Years        48.3
# 473  2016  15-19 Years        51.2
# 474  2017  15-19 Years        51.5
# 475  2018  15-19 Years        49.2
#
# [476 rows x 3 columns]

# %%
df.pivot(index='Year', columns='Age Group', values='Death Rate').plot()
# Out:
# <Axes: xlabel='Year'>

# %%
df.pivot(index='Year', columns='Age Group')['Death Rate'].plot()
# Out:
# <Axes: xlabel='Year'>
